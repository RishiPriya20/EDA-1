# %% [markdown]
#                                      **EXPLORATORY DATA ANALYSIS ON A DATASET**

# %% [markdown]
# **Objecctive**

# %% [markdown]
# The main goal is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure.

# %% [markdown]
# **Load Data**

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\rishi\\OneDrive\\Desktop\\DS Assigments\\cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()

# %% [markdown]
# **Data Cleaning**

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# **Handle missing values**

# %%
missing_values = df.isnull().sum()
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# **Detect and handle outliers**

# %%
import numpy as np
df = df[(np.abs(df - df.mean()) <= (3*df.std())).all(axis=1)]

# %%
**Obsevation**

# %% [markdown]
# these codes checks for missing values in dataset.The 'df.isnull' function it returns a Data frame of the same shape as 'df'
# with 'True' for entries .By chaining the 'sum()' function it provides the total count of misssing values for each column in the dataset.It is crucial for the data cleaning process because it helps identify columns with missing data that need to be addressed
# the code df =df[(np.abs(df - df.mean()) <= (3 * df.std())).all(axis=1)] it filters the data frame to keep only rows where all values are within 3 standard deviations from the mean

# %% [markdown]
# **statistical summary**

# %%
summary_stats = df.describe()
summary_stats
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1213.000000  1213.000000  1213.000000  1213.000000  1213.000000
# mean    133.492168     0.003458     0.001180     0.004483     0.001248
# std       9.760287     0.003675     0.002481     0.002785     0.002023
# min     106.000000    -0.000185    -0.005106    -0.000132    -0.000124
# 25%     126.000000     0.000000     0.000000     0.002502     0.000000
# 50%     134.000000     0.002410     0.000000     0.004587     0.000000
# 75%     141.000000     0.006090     0.001241     0.006579     0.001949
# max     160.000000     0.014068     0.012510     0.012072     0.007692
#
#                  DS            DP         ASTV         MSTV         ALTV  \
# count  1.213000e+03  1.213000e+03  1213.000000  1213.000000  1213.000000
# mean  -5.185573e-11  7.165182e-08    45.313927     1.141304     6.755964
# std    1.737785e-09  1.197387e-06    15.660129     0.546457    11.009470
# ...

# %% [markdown]
# **Observation**

# %% [markdown]
# the df.describe() functio generates summary statistics for each numerical column in the dataset
# count: The number of non-null values in each column
# Mean: The average value of each column
# Standard deviation: Measures the variability of the value
# Minimum: The smallest value in each column
# 25%:The value below which 255 of the data falls
# 50%: The value below which is 75% of the data falls
# 75%: The value below which 75% of the data
# Maximum:The largest value in each column

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# **Histogram**

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# **Observation**

# %% [markdown]
# code generates the histogram for all numerical columns in the dataset and asks to display them in 10 * 10 inch figure. The 'df.hist()' function creates a histogram for each column and shows the frequency distribution of the data
# By giving 'figsize=(10,10)' argument then the histogram is displayed in a larger format and 'plt.show()' it shows the plots
# The histogram provides a quick visual summary of the distribution of each variable in the dataset. They help in identifying patterns, like whether the data is normally distributed, skewed, or has outliers. So these visualizations are crucial for understanding the data's overall structure and guiding future analysis steps

# %% [markdown]
# **Boxplot**

# %%
import seaborn as sns
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# **Observation**

# %% [markdown]
# This code generates boxplots for all numerical columns in the dataset using 'seaborn' library.
# The 'sns.boxplot(data=df)' function creates a boxplot for each numerical column and it is a graphical representation of the data distribution based on 5 number summary are: minimum,25%, median(50%),75%, and maximum 'plt.show()' is used to display the boxplots
# The Boxplots are useful for visualizing the distribution, central tendency, and variability of data. They help identify outliers and understand the spread of the data

# %% [markdown]
# **Correlation heatmap**

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Observation**

# %% [markdown]
# This code generates a heatmap to visualize the correlation matrix of the dataset's numerical variables
# The 'df.corr()' function calculates the pairwise correlation coefficient between the numerical columns in the data frame.
# The 'sns.heatmap()' function from 'seaborn' library is then used to create a heatmap of this correlation matrix 'annot = True ' displays the correlation values within the heatmap and cmap=collwarm provides a color gradient for better visualization and 'plt.show()' is used to display the heatmap()

# %% [markdown]
# **Pattern Recognition and Insights**

# %% [markdown]
# **Correlation Analysis**

# %%
corr_matrix = df.corr()
corr
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.066746 -0.042614 -0.065652 -0.041522 -0.022581
# AC       -0.066746  1.000000  0.008148  0.126641  0.011756 -0.017178
# FM       -0.042614  0.008148  1.000000 -0.288495  0.007383  0.014213
# UC       -0.065652  0.126641 -0.288495  1.000000  0.225412 -0.023489
# DL       -0.041522  0.011756  0.007383  0.225412  1.000000  0.015030
# DS       -0.022581 -0.017178  0.014213 -0.023489  0.015030  1.000000
# DP       -0.010207  0.026439 -0.014108  0.005269  0.015982  0.001787
# ASTV      0.343648 -0.162805  0.233161 -0.150486 -0.132552 -0.023843
# MSTV     -0.322672  0.317266  0.008987  0.215342  0.530092  0.026406
# ALTV      0.249244 -0.419668 -0.005905 -0.183630 -0.190345  0.018327
# MLTV     -0.090989 -0.334363 -0.025628 -0.100421 -0.181487  0.004227
# Width    -0.031502  0.340870  0.163070  0.018100  0.539172  0.020168
# Tendency  0.263819 -0.036771 -0.054232 -0.052030  0.273956  0.015295
# ...

# %% [markdown]
# **Observation**

# %% [raw]
# This code calculates the correlation matrix for the numerical columns in the dataset and displays it. The 'df.corr()' function computes the pairwise correlation coefficient between the numerical columns and it gives a correlation matrix. This matrix shows how strongly each pair of variables is linearly related to each other.
# The correlation matrix helps identify the strength and direction of linear relationships between variables.
# Understanding these relationships is important for analyzing how variables influence each other and for identifying multicollinearity in the dataset

# %% [markdown]
# **Conclusion**

# %% [markdown]
# This conclusion connects all parts of the analysis, gives a clear summary of what we found and explains why  these findings are important in a simple way
